# %%
from openai import OpenAI
client = OpenAI()

# %% [markdown]
# ## Ask the model for a command

# %%
resp = client.chat.completions.create(model='gpt-4o', messages=msgs)
reply = resp.choices[0].message.content
exec(reply)
